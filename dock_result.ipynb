# %%
import numpy as np
from scipy.stats import pearsonr, spearmanr

#glp1
##glide
experimental_binding_affinity_1 = [101.745,84.5,84.5,84.5,4074]
predicted_binding_affinity_1 = [-10.8,-9.654,-12.106,-11.989,-5.454]
# 计算 Pearson 相关系数（rp）
rp1, _ = pearsonr(experimental_binding_affinity_1, predicted_binding_affinity_1)
# 计算 Spearman 相关系数（rs）
rs1, _ = spearmanr(experimental_binding_affinity_1, predicted_binding_affinity_1)
## ledock
experimental_binding_affinity_2 = [101.745,84.5,84.5,200.4]
predicted_binding_affinity_2 = [-9.1,-11.6,-10.83,-11.2]
rp2, _ = pearsonr(experimental_binding_affinity_2, predicted_binding_affinity_2)
rs2, _ = spearmanr(experimental_binding_affinity_2, predicted_binding_affinity_2)
## MOE
experimental_binding_affinity_3 = [101.745,84.5,84.5,4074,84.5,200.4]
predicted_binding_affinity_3 = [-9.91,-12.79,-10.58,-10.89,-9.92,-12.9]
rp3, _ = pearsonr(experimental_binding_affinity_3, predicted_binding_affinity_3)
rs3, _ = spearmanr(experimental_binding_affinity_3, predicted_binding_affinity_3)
## VINA
experimental_binding_affinity_4 = [101.745,84.5,84.5,84.5,84.5,200.4]
predicted_binding_affinity_4 = [-10.8,-13.5,-12.6,-12.5,-13.1,-15.9]
rp4, _ = pearsonr(experimental_binding_affinity_4, predicted_binding_affinity_4)
rs4, _ = spearmanr(experimental_binding_affinity_4, predicted_binding_affinity_4)
print(rp1,rs1)
print(rp2,rs2)
print(rp3,rs3)
print(rp4,rs4)
# Out:
# 0.9312021802314179 0.6708203932499368
# -0.1777847439266 0.21081851067789195
# 0.08362790746472656 -0.27322953332351235
# -0.7476811608813944 -0.1690308509457033

# %%
# HPK1
# Glide
exp_aff_1 = [16,16,16,50.43,89,4001,258.94,226.625]
pred_aff_1 = [-9.95,-9.77,-9.34,-9.08,-7.9,-9.14,-10.065,-10.717]
rp1, _ = pearsonr(exp_aff_1, pred_aff_1)
rs1, _ = spearmanr(exp_aff_1, pred_aff_1)

# Ledock
exp_aff_2 = [16,16,16,50.43,89,258.94,226.625]
pred_aff_2 = [-6.55,-6.79,-7.81,-8.71,-6.91,-6.86,-7.97]
rp2, _ = pearsonr(exp_aff_2, pred_aff_2)
rs2, _ = spearmanr(exp_aff_2, pred_aff_2)

#MOE
exp_aff_3 = [16,16,16,50.43,89,258.94,226.625]
pred_aff_3 = [-8.21,-8.04,-9.46,-9.06,-8.44,-7.37,-9.92]
rp3, _ = pearsonr(exp_aff_3, pred_aff_3)
rs3, _ = spearmanr(exp_aff_3, pred_aff_3)

# VINA
exp_aff_4 = [16,16,50.43,89,4001,258.94,226.625]
pred_aff_4 = [-7.9,-9.4,-9.4,-8.8,-10.1,-8.3,-9]
rp4, _ = pearsonr(exp_aff_4, pred_aff_4)
rs4, _ = spearmanr(exp_aff_4, pred_aff_4)
print(rp1,rs1)
print(rp2,rs2)
print(rp3,rs3)
print(rp4,rs4)
# Out:
# 0.14100558688524656 -0.048795003647426664
# -0.02853553646280782 -0.3335621924974956
# 0.07374586981604109 0.03706246583305506
# -0.6552608141295545 -0.2636363636363636

# %%
# LRRK2
# Glide
exp_aff_1 = [47,1,48,108,358.2,1.17]
pred_aff_1 = [-11.005,-14.273,-11.304,-7.191,-9.586,-8.135]
rp1, _ = pearsonr(exp_aff_1, pred_aff_1)
rs1, _ = spearmanr(exp_aff_1, pred_aff_1)

# Ledock
exp_aff_2 = [47,1,47,47,48,108,358.2,464,1.17]
pred_aff_2 = [-9.87,-7.25,-10.3,-9.64,-10.37,-7.35,-9.36,-8.69,-7.57]
rp2, _ = pearsonr(exp_aff_2, pred_aff_2)
rs2, _ = spearmanr(exp_aff_2, pred_aff_2)

#MOE
exp_aff_3 = [47,1,47,47,48,108,1.17]
pred_aff_3 = [-11.53,-8.89,-11.52,-10.62,-11.5,-6.81,-8.9]
rp3, _ = pearsonr(exp_aff_3, pred_aff_3)
rs3, _ = spearmanr(exp_aff_3, pred_aff_3)

# VINA
exp_aff_4 = [47,1,47,47,48,108,358.2,464,1.17]
pred_aff_4 = [-12.9,-7.3,-13.2,-12.3,-12.6,-7.3,-10.1,-7.8,-7.3]
rp4, _ = pearsonr(exp_aff_4, pred_aff_4)
rs4, _ = spearmanr(exp_aff_4, pred_aff_4)
print(rp1,rs1)
print(rp2,rs2)
print(rp3,rs3)
print(rp4,rs4)
# Out:
# 0.27979620669871 0.48571428571428577
# -0.044970149265264485 -0.16951587590520262
# 0.23488217134756434 -0.03706246583305506
# 0.2403888977249924 -0.08620689655172416

# %%
import numpy as np
import matplotlib.pyplot as plt

# 模拟数据：3个靶点，每个靶点有4个软件
targets = ["GLP-1R", "HPK1", "LRRK2"]
softwares = ["Glide_SP", "LeDock", "MOE Dock", "Autodock vina"]
rmsd_bins = np.array([0, 2, 4, 6, 8, 10])  # RMSD 轴

# 生成随机数据（假设四个软件的 RMSD 分布）
np.random.seed(42)
data = {
    "GLP-1R": {"Glide_SP": np.array([0,0.25,0.56,0.69,0.84,0.91]), 
               "LeDock": np.array([0,0.06,0.25,0.49,0.58,0.67]), 
               "MOE Dock": np.array([0,0.333333333,0.647058824,0.745098039,0.764705882,0.803921569]), 
               "Autodock vina": np.array([0,0.11,0.32,0.4,0.53,0.68])},
    "HPK1": {"Glide_SP": np.array([0,0.23,0.67,0.79,0.94,1]), 
             "LeDock": np.array([0,0.15,0.28,0.395,0.485,0.535]), 
             "MOE Dock": np.array([0,0.23,0.53,0.8,0.91,0.98]), 
             "Autodock vina": np.array([0,0.065,0.21,0.435,0.73,0.935])},
    "LRRK2": {"Glide_SP": np.array([0,0.3,0.88,1,1,1]), 
              "LeDock": np.array([0,0.41,0.66,0.74,0.84,0.95]), 
              "MOE Dock": np.array([0,0.25,0.42,0.47,0.5,0.52]), 
              "Autodock vina": np.array([0,0.015,0.12,0.27,0.488,0.65])}
}

# 绘图
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, target in enumerate(targets):
    ax = axes[i]
    
    for software in softwares:
        ax.plot(rmsd_bins, data[target][software], marker='o', label=software)
    ax.axvline(x=2, linestyle="--", color="grey", alpha=0.7, label="RMSD = 2.0")
    
    ax.set_title(target, fontsize=18)
    ax.set_xlabel("RMSD", fontsize=16)
    ax.set_xticks(rmsd_bins, fontsize=16)
    ax.tick_params(axis='both', labelsize=14)
    ax.set_ylim(0, 1.0)
    # ax.grid(True, linestyle='--', alpha=0.6)

# 统一 Y 轴标签
    ax.set_ylabel("Cumulative Frequency", fontsize=16)

# 添加图例
axes[-1].legend(title="Software", loc="upper right",fontsize=14, title_fontsize=16)

plt.tight_layout()
plt.savefig('docking_power.svg', dpi=600)
plt.show()

# %%
import torch
from tqdm import tqdm
import pandas as pd

from src.datasets.pharmacophore_eval import match_score
from dgl.data.utils import load_graphs
from rdkit import Chem
import csv
from src.eval import sascorer
from rdkit.Chem import QED, AllChem
import joblib
def process_mol(args):
    mol, pp_graph_list, loaded_reg = args
    if mol is None:
        return (0, 0, 0, 0)  # 如果分子无效，返回默认值
    else:
        pharma_match_score_list = [match_score(mol, pp_graph) for pp_graph in pp_graph_list]
        return (
            max(pharma_match_score_list),
            sascorer.calculateScore(mol) * 0.1,
            QED.default(mol),
            loaded_reg.predict([AllChem.GetMorganFingerprintAsBitVect(mol, 2, 1024)]).item()
        )

pp_graph_list, _ = load_graphs("./data/PDK1_pdb/pdk1_phar_graphs.bin")
for pp_graph in pp_graph_list:
    pp_graph.ndata['h'] = \
        torch.cat((pp_graph.ndata['type'], pp_graph.ndata['size'].reshape(-1, 1)), dim=1).float()
    pp_graph.edata['h'] = pp_graph.edata['dist'].reshape(-1, 1).float()
loaded_reg = joblib.load('./data/stacking_regressor_model_1.pkl')

# %%
import multiprocessing, writer


with multiprocessing.Pool(10) as pool:
        # 使用 tqdm 迭代并监视分子列表
        for result in tqdm(pool.imap_unordered(process_mol, [(smiles, pp_graph_list, loaded_reg) for smiles in val_data['SMILES'].values]), total=len(val_data['SMILES'].values)):
            writer.writerow(result)

        pool.close()
